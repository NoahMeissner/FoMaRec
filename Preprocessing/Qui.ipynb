# %% [markdown]
# ## Ground Truth Dataset Kochbar Cleaned

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Load Data

# %%
df_full = pd.read_csv("Data/dataset.csv")
df_samples_flavor = pd.read_csv("Data/kb_samples_flavors.csv")
df_flavors = pd.read_csv("Data/kb_tb_flavors.csv")

# %%
len(df_flavors)
# Out:
# 55496

# %%
len(df_flavors['recipe_id'].unique())
# Out:
# 5000

# %%
df_full
# Out:
#         Unnamed: 0                                        recipe_href  \
# 0                0  /rezept/501707/Gefuellte-Zucchini-und-Paprika....
# 1                1  /rezept/501195/Haehnchensteaks-mit-Austernpilz...
# 2                2  /rezept/501146/Mistkratzerli-aus-der-Schweiz-H...
# 3                3          /rezept/500992/Moehren-Paprika-Suppe.html
# 4                4            /rezept/500793/Gesundes-Abendessen.html
# ...            ...                                                ...
# 405859      405859          /rezept/99993/Winterpunsch-Hot-Apple.html
# 405860      405860  /rezept/99996/Ananas-Schnitzel-ueberbacken-mit...
# 405861      405861          /rezept/99997/Schlemmer-Fischspiesse.html
# 405862      405862                   /rezept/99998/Eier-Senf-Dip.html
# 405863      405863       /rezept/99999/Huehnersalat-a-la-Vietnam.html
#
#                                                     title  Bewertungen  \
# ...

# %% [markdown]
# impor
